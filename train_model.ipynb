# %%
import tensorflow as tf

import scipy
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import os
import numpy as np
import matplotlib.pyplot as plt

# %%
PATH = './Images'
train_dir = os.path.join(PATH, 'train')
validation_dir = os.path.join(PATH, 'validation')
test_dir = os.path.join(PATH, '')

# %%
total_train = sum([len(files) for r, d, files in os.walk(train_dir)])
total_val = sum([len(files) for r, d, files in os.walk(validation_dir)])
total_test = len(os.listdir(test_dir))

# %%
batch_size = 64
epochs = 42
IMG_HEIGHT = 150
IMG_WIDTH = 150

# %%
train_image_generator = ImageDataGenerator(rescale = 1./255)
validation_image_generator = ImageDataGenerator(rescale = 1./255)
test_image_generator = ImageDataGenerator(rescale = 1./255)

train_data_gen = train_image_generator.flow_from_directory(
  directory = train_dir,
  target_size = (IMG_HEIGHT, IMG_WIDTH),
  batch_size = batch_size,
)
val_data_gen = validation_image_generator.flow_from_directory(
  directory = validation_dir,
  target_size = (IMG_HEIGHT, IMG_WIDTH),
  batch_size = batch_size,
)
test_data_gen = test_image_generator.flow_from_directory(
  directory = test_dir,
  classes = ['test'],
  target_size = (IMG_HEIGHT, IMG_WIDTH),
  batch_size = batch_size,
  shuffle = False
)
# Out:
# Found 128 images belonging to 4 classes.
# Found 36 images belonging to 4 classes.
# Found 9 images belonging to 1 classes.

# %%
def plotImages(images_arr, probabilities = False, labels = False):
    fig, axes = plt.subplots(len(images_arr), 1, figsize=(5,len(images_arr) * 3))
    if probabilities is False:
      for img, ax in zip( images_arr, axes):
          ax.imshow(img)
          ax.axis('off')
    else:
      for img, probability, ax, label in zip( images_arr, probabilities, axes, labels):
            ax.imshow(img)
            ax.axis('off')
            ax.set_title(f"{label} - {'%.3f'%(probability*100)}")
    plt.show()

sample_training_images, _ = next(train_data_gen)
plotImages(sample_training_images[:5])

# %%
train_image_generator = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 90,
    horizontal_flip = True,
    vertical_flip = True,
    zoom_range = [0.9, 1.1],
    shear_range = 0.2
)
train_data_gen = train_image_generator.flow_from_directory(batch_size=batch_size,
                                                     directory=train_dir,
                                                     target_size=(IMG_HEIGHT, IMG_WIDTH))

augmented_images = [train_data_gen[0][0][0] for i in range(5)]

plotImages(augmented_images)
# Out:
# Found 128 images belonging to 4 classes.

# %%
train_data_gen = train_image_generator.flow_from_directory(batch_size=batch_size,
                                                     directory=train_dir,
                                                     target_size=(IMG_HEIGHT, IMG_WIDTH))
# Out:
# Found 128 images belonging to 4 classes.

# %%
model = Sequential()
model.add(Conv2D(32, (6,6), padding='same', activation='relu', input_shape=(150,150,3)))
model.add(MaxPooling2D(4,4))
model.add(Flatten())
model.add(Dense(32, input_dim=745))
model.add(Dense(32, input_dim=745))
model.add(Dropout(.2))
model.add(Dense(4, activation='softmax'))


model.build(input_shape = [IMG_HEIGHT, IMG_WIDTH])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 150, 150, 32)      3488
#
#  max_pooling2d_4 (MaxPooling  (None, 37, 37, 32)       0
#  2D)
#
#  flatten_3 (Flatten)         (None, 43808)             0
#
#  dense_8 (Dense)             (None, 32)                1401888
#
#  dense_9 (Dense)             (None, 32)                1056
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_10 (Dense)            (None, 4)                 132
#
# =================================================================
# Total params: 1,406,564
# Trainable params: 1,406,564
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False,
                                                    label_smoothing=0.0,
                                                    axis=-1),
    metrics = ['accuracy']
    )

# %%
history = model.fit(
    x = train_data_gen,
    epochs = epochs,
    batch_size = batch_size,
    steps_per_epoch = 1,
    validation_data = val_data_gen,
    validation_steps = 1
    )
# Out:
# Epoch 1/42
# 1/1 [==============================] - 2s 2s/step - loss: 1.3459 - accuracy: 0.2812 - val_loss: 3.7036 - val_accuracy: 0.2500
# Epoch 2/42
# 1/1 [==============================] - 1s 640ms/step - loss: 5.3116 - accuracy: 0.2344 - val_loss: 1.3421 - val_accuracy: 0.5833
# Epoch 3/42
# 1/1 [==============================] - 1s 697ms/step - loss: 1.5366 - accuracy: 0.5312 - val_loss: 2.7717 - val_accuracy: 0.5000
# Epoch 4/42
# 1/1 [==============================] - 1s 648ms/step - loss: 3.0816 - accuracy: 0.4219 - val_loss: 1.8943 - val_accuracy: 0.5278
# Epoch 5/42
# 1/1 [==============================] - 1s 693ms/step - loss: 2.0748 - accuracy: 0.4844 - val_loss: 0.9886 - val_accuracy: 0.6667
# Epoch 6/42
# 1/1 [==============================] - 1s 663ms/step - loss: 1.1551 - accuracy: 0.4844 - val_loss: 0.9921 - val_accuracy: 0.5000
# Epoch 7/42
# 1/1 [==============================] - 1s 648ms/step - loss: 1.0362 - accuracy: 0.5469 - val_loss: 0.8095 - val_accuracy: 0.6667
# Epoch 8/42
# 1/1 [==============================] - 1s 641ms/step - loss: 1.0732 - accuracy: 0.5156 - val_loss: 0.7986 - val_accuracy: 0.6667
# Epoch 9/42
# 1/1 [==============================] - 1s 679ms/step - loss: 0.8569 - accuracy: 0.6562 - val_loss: 0.7869 - val_accuracy: 0.6389
# Epoch 10/42
# 1/1 [==============================] - 1s 655ms/step - loss: 0.8146 - accuracy: 0.6562 - val_loss: 0.7916 - val_accuracy: 0.6111
# Epoch 11/42
# 1/1 [==============================] - 1s 643ms/step - loss: 0.8944 - accuracy: 0.5781 - val_loss: 0.7668 - val_accuracy: 0.6111
# Epoch 12/42
# 1/1 [==============================] - 1s 647ms/step - loss: 0.7721 - accuracy: 0.6719 - val_loss: 0.7312 - val_accuracy: 0.6667
# Epoch 13/42
# 1/1 [==============================] - 1s 763ms/step - loss: 0.8208 - accuracy: 0.6250 - val_loss: 0.6597 - val_accuracy: 0.6667
# Epoch 14/42
# 1/1 [==============================] - 1s 719ms/step - loss: 0.7230 - accuracy: 0.7344 - val_loss: 0.6075 - val_accuracy: 0.6944
# Epoch 15/42
# 1/1 [==============================] - 1s 691ms/step - loss: 0.6087 - accuracy: 0.7500 - val_loss: 0.5351 - val_accuracy: 0.7500
# Epoch 16/42
# 1/1 [==============================] - 1s 651ms/step - loss: 0.6100 - accuracy: 0.7656 - val_loss: 0.4871 - val_accuracy: 0.7500
# Epoch 17/42
# 1/1 [==============================] - 1s 624ms/step - loss: 0.4912 - accuracy: 0.7656 - val_loss: 0.3875 - val_accuracy: 0.8056
# Epoch 18/42
# 1/1 [==============================] - 1s 734ms/step - loss: 0.3602 - accuracy: 0.9531 - val_loss: 0.3573 - val_accuracy: 0.8889
# Epoch 19/42
# 1/1 [==============================] - 1s 685ms/step - loss: 0.4041 - accuracy: 0.8906 - val_loss: 0.2997 - val_accuracy: 0.9722
# Epoch 20/42
# 1/1 [==============================] - 1s 652ms/step - loss: 0.2538 - accuracy: 0.9688 - val_loss: 0.2841 - val_accuracy: 0.9167
# Epoch 21/42
# 1/1 [==============================] - 1s 638ms/step - loss: 0.3280 - accuracy: 0.8594 - val_loss: 0.3102 - val_accuracy: 0.9167
# Epoch 22/42
# 1/1 [==============================] - 1s 677ms/step - loss: 0.2884 - accuracy: 0.9219 - val_loss: 0.3550 - val_accuracy: 0.8889
# Epoch 23/42
# 1/1 [==============================] - 1s 639ms/step - loss: 0.3418 - accuracy: 0.8750 - val_loss: 0.2471 - val_accuracy: 0.9444
# Epoch 24/42
# 1/1 [==============================] - 1s 663ms/step - loss: 0.1743 - accuracy: 0.9531 - val_loss: 0.2696 - val_accuracy: 0.8611
# Epoch 25/42
# 1/1 [==============================] - 1s 685ms/step - loss: 0.4268 - accuracy: 0.8438 - val_loss: 0.2427 - val_accuracy: 0.9444
# Epoch 26/42
# 1/1 [==============================] - 1s 685ms/step - loss: 0.2448 - accuracy: 0.9375 - val_loss: 0.3019 - val_accuracy: 0.8611
# Epoch 27/42
# 1/1 [==============================] - 1s 643ms/step - loss: 0.2008 - accuracy: 0.9375 - val_loss: 0.2384 - val_accuracy: 0.9167
# Epoch 28/42
# 1/1 [==============================] - 1s 669ms/step - loss: 0.1424 - accuracy: 1.0000 - val_loss: 0.1911 - val_accuracy: 0.9167
# Epoch 29/42
# 1/1 [==============================] - 1s 671ms/step - loss: 0.1513 - accuracy: 0.9844 - val_loss: 0.1793 - val_accuracy: 0.9444
# Epoch 30/42
# 1/1 [==============================] - 1s 682ms/step - loss: 0.1541 - accuracy: 0.9219 - val_loss: 0.1916 - val_accuracy: 0.9444
# Epoch 31/42
# 1/1 [==============================] - 1s 673ms/step - loss: 0.0972 - accuracy: 1.0000 - val_loss: 0.2189 - val_accuracy: 0.9167
# Epoch 32/42
# 1/1 [==============================] - 1s 689ms/step - loss: 0.1172 - accuracy: 0.9531 - val_loss: 0.2874 - val_accuracy: 0.8889
# Epoch 33/42
# 1/1 [==============================] - 1s 691ms/step - loss: 0.1175 - accuracy: 1.0000 - val_loss: 0.2357 - val_accuracy: 0.8889
# Epoch 34/42
# 1/1 [==============================] - 1s 722ms/step - loss: 0.1476 - accuracy: 0.9688 - val_loss: 0.1905 - val_accuracy: 0.9444
# Epoch 35/42
# 1/1 [==============================] - 1s 671ms/step - loss: 0.1631 - accuracy: 0.9688 - val_loss: 0.1555 - val_accuracy: 0.9444
# Epoch 36/42
# 1/1 [==============================] - 1s 697ms/step - loss: 0.1365 - accuracy: 0.9531 - val_loss: 0.1466 - val_accuracy: 0.9722
# Epoch 37/42
# 1/1 [==============================] - 1s 787ms/step - loss: 0.1183 - accuracy: 0.9531 - val_loss: 0.1452 - val_accuracy: 0.9444
# Epoch 38/42
# 1/1 [==============================] - 1s 731ms/step - loss: 0.1257 - accuracy: 0.9688 - val_loss: 0.1650 - val_accuracy: 0.9167
# Epoch 39/42
# 1/1 [==============================] - 1s 699ms/step - loss: 0.1118 - accuracy: 0.9844 - val_loss: 0.2272 - val_accuracy: 0.9167
# Epoch 40/42
# 1/1 [==============================] - 1s 665ms/step - loss: 0.1106 - accuracy: 0.9688 - val_loss: 0.1762 - val_accuracy: 0.9167
# Epoch 41/42
# 1/1 [==============================] - 1s 623ms/step - loss: 0.0690 - accuracy: 0.9844 - val_loss: 0.1508 - val_accuracy: 0.9444
# Epoch 42/42
# 1/1 [==============================] - 1s 735ms/step - loss: 0.0714 - accuracy: 0.9844 - val_loss: 0.1592 - val_accuracy: 0.9444

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#save model

model.save('./model/model.h5')

# %%
probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])
predictions = probability_model.predict(test_data_gen)

test_images, _ = next(test_data_gen)

predictionPercent = []
predictionLabel = []
name = ["clip", "dark glass", "frame", "strip"]
for i in range(len(predictions)):
    value = 0
    category = 0
    for j in range(len(predictions[i])):
        if predictions[i][j] > value:
            value = predictions[i][j]
            category = j
    predictionPercent.append(value)
    predictionLabel.append(name[category])

plotImages(test_images, predictionPercent, predictionLabel)
# Out:
# 1/1 [==============================] - 0s 110ms/step
